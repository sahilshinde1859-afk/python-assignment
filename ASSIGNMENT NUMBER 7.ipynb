# %%
#Question number 1
t=(10,20,30)
print("tuple",t)
print("lenth",len(t))
print("concatenation",t+(40,50))
print("repetation",t*2)
print("membership",20 in t)
# Out:
# tuple (10, 20, 30)
# lenth 3
# concatenation (10, 20, 30, 40, 50)
# repetation (10, 20, 30, 10, 20, 30)
# membership True

# %%
#Question number 2
t=(10,20,30,40,50)
print(t[0])
print(t)
print(t[1:4])
for i in t :
        print(i)
# Out:
# 10
# (10, 20, 30, 40, 50)
# (20, 30, 40)
# 10
# 20
# 30
# 40
# 50

# %%
#question number 3
t= (1,2,3)
print(t)
del(t)
print("tuple deleted ")
# Out:
# (1, 2, 3)
# tuple deleted

# %%
#Question number 4
t= (5,2,9,1)
print(len(t))
print(max(t))
print(min(t))
print(tuple[1,2,3])
# Out:
# 4
# 9
# 1
# tuple[1, 2, 3]
