# %% [markdown]
# <a href="https://colab.research.google.com/github/sahilshinde1859-afk/python-assignment/blob/main/ASSIGNMENT_NO_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ASSIGNMENT NUMBER 2

# %%
# que 1 - write a programme to add two numbers in python
a= int (input("enter the first number :"))
b= int (input ("enter the second number :"))
sum = (a+b)
print("the sum is ",sum)
# Out:
# enter the first number :20
# enter the second number :22
# the sum is  42

# %%
# questabion no 2 - WAP to declare variables and display type of respective variable
a=10
b= "sahil"
c= 10.06
d=(100,200)
e= True

print(type(a))
print(type(b))
print(type(c))
print(type(d))
print(type(e))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'tuple'>
# <class 'bool'>
