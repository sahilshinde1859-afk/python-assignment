# %%
#Question number 1
numbers=[10,20,30,40,50]
print(30 in numbers)
print(100 in numbers)
# Out:
# True
# False

# %%
#Question number 2
fruit= ["apple","banana","mango","orange","grapes"]
print ("first element:",fruit[0] )
print ("last element :",fruit[-1])
print ("element from index 1 to 3",fruit[1:4])
# Out:
# first element: apple
# last element : grapes
# element from index 1 to 3 ['banana', 'mango', 'orange']

# %%
#Question number 3
colours=["red","blue","green"]
colours[1]="yellow"
print("after update : ",colours )

colours.append("purple")
print ("after append : ",colours)

colours.insert(4,"black")
print ("after insert : ",colours)

colours.remove("green")
print("after remove :",colours)

del colours[0]
print ("after delete : ", colours )
# Out:
# after update :  ['red', 'yellow', 'green']
# after append :  ['red', 'yellow', 'green', 'purple']
# after insert :  ['red', 'yellow', 'green', 'purple', 'black']
# after remove : ['red', 'yellow', 'purple', 'black']
# after delete :  ['yellow', 'purple', 'black']

# %%
#question number 4
list1=[1,2,3]
list2=[4,5,6]
print ("concatenation",list1 + list2)
print ("repetation", list1 *2 , list2*3)
print ("lenth of list 1:",len(list1))
print ("maximum element in list 1: ", max(list1))
print ("minimum element in list 2 :",min (list2))
# Out:
# concatenation [1, 2, 3, 4, 5, 6]
# repetation [1, 2, 3, 1, 2, 3] [4, 5, 6, 4, 5, 6, 4, 5, 6]
# lenth of list 1: 3
# maximum element in list 1:  3
# minimum element in list 2 : 4
