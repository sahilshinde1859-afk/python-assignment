# %%
# assignment number 8

# %%
#question number 01
d1={"a":5,"b":2,"c":8}
asc=dict(sorted(d1.items(),key=lambda x:x[1]))
print("ascending:",asc)
disc=dict(sorted(d1.items(),key = lambda x:x[1],reverse=True))
print("descending",disc)
# Out:
# ascending: {'b': 2, 'a': 5, 'c': 8}
# descending {'c': 8, 'a': 5, 'b': 2}

# %%
#question number 2
d2={"name":"shubh","age":18}
key=input("enter key :")
if key in d2 :
    print ("Key  exist")
else:
    print("Key does not exist")
# Out:
# enter key : age
# Key  exist

# %%
#question number 3
d3={"a":1,"b":2}
d4={"c":3,"d":4}
d3.update(d4)
print("merged dictionary",d3)
# Out:
# merged dictionary {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %%
#QUESTION 4
t1=(1,2,3)
t1=t1+(4,)
print("updated tuple:",t1)
# Out:
# updated tuple: (1, 2, 3, 4)

# %%
#Question number 5
t2= (10,"hello",3.5,False)
print(t2)
print(type(t2))
# Out:
# (10, 'hello', 3.5, False)
# <class 'tuple'>

# %%
#Question number 6
l1=[10,20,30,40]
total=sum(l1)
print("sum is ", total)
# Out:
# sum is  100

# %%
#Question number 7
l2= [10, 28 , 16, 26 ,42]
largest=max(l2)
print("largest number is :",largest)
# Out:
# largest number is : 42

# %%
#question number 8
s={1,2,3}
s.add(4)
s.update([5,6])
print("s",s)
# Out:
# s {1, 2, 3, 4, 5, 6}

# %%
#Question number 9
from array import*
a1= array("i",[1,2,3,4,5])
a1.reverse()
print("a1 is :",a1)
# Out:
# a1 is : array('i', [5, 4, 3, 2, 1])

# %%
#Question  number 10
from array import*
a2= array("i",[10,20,30,40,50])
for i in range (4):
    print("element at index :",i,"=",a2[i])
# Out:
# element at index : 0 = 10
# element at index : 1 = 20
# element at index : 2 = 30
# element at index : 3 = 40
