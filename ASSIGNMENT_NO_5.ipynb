# %% [markdown]
# <a href="https://colab.research.google.com/github/sahilshinde1859-afk/python-assignment/blob/main/ASSIGNMENT_NO_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#QUE 1 -
str= input ("enter any string ")
a=len(str)
print ("length of string is :",a)
# Out:
# enter any string sahil shashikant shinde
# length of string is : 24

# %%
#Que no 2
str=input ("enter any string whose lenght is greater than 3")
new_string=str[2]+str[-2]
print("new string",new_string)
# Out:
# enter any string whose lenght is greater than 3sahil shinde
# new string hd

# %%
#que no 3
str1=input("enter any string")
str2=input("enter any string ")
newstring= str1+str2
print ("concated string:",newstring)
# Out:
# enter any stringsahil shinde
# enter any string warnul
# concated string: sahil shinde warnul
